# %%
# !pip install pandas numpy scikit-learn matplotlib notebook

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Step 2: Create Model Metadata
model_metadata = {
    "Model Name": "Loan Approval Prediction Model",
    "Model Version": "1.0",
    "Business Owner": "Consumer Lending Department",
    "Model Owner": "Responsible AI Team",
    "Use Case": "Predict whether a loan application should be approved",
    "Model Type": "Classification Model",
    "Deployment Status": "Pre-Deployment Review",
    "Created Date": datetime.today().strftime("%Y-%m-%d")
}
 
model_metadata
# Out:
# {'Model Name': 'Loan Approval Prediction Model',
#  'Model Version': '1.0',
#  'Business Owner': 'Consumer Lending Department',
#  'Model Owner': 'Responsible AI Team',
#  'Use Case': 'Predict whether a loan application should be approved',
#  'Model Type': 'Classification Model',
#  'Deployment Status': 'Pre-Deployment Review',
#  'Created Date': '2026-06-20'}

# %%
# Step 4: Create Model Card
model_card = f"""
# Model Card
 
## Model Overview
Model Name: {model_metadata["Model Name"]}
 
Model Version: {model_metadata["Model Version"]}
 
Business Owner: {model_metadata["Business Owner"]}
 
Model Owner: {model_metadata["Model Owner"]}
 
Use Case: {model_metadata["Use Case"]}
 
Model Type: {model_metadata["Model Type"]}
 
Deployment Status: {model_metadata["Deployment Status"]}
 
Created Date: {model_metadata["Created Date"]}
 
## Intended Use
This model is intended to support loan approval decision-making by predicting whether an applicant is likely to qualify for a loan based on financial and application-related attributes.
 
## Not Intended Use
This model should not be used as the sole basis for final lending decisions without human review. It should not be used for unrelated credit, employment, insurance, or eligibility decisions.
 
## Performance Considerations
The model must be evaluated for accuracy, fairness, explainability, robustness, and compliance before production deployment.
 
## Fairness Considerations
The model should be evaluated across protected attributes such as gender and age to identify potential disparities in approval rates, false positives, and false negatives.
 
## Limitations
The model may reflect patterns present in historical lending data. If historical data contains bias, the model may reproduce or amplify those patterns.
 
## Human Oversight
Final loan approval decisions should include human review, especially for borderline, denied, or high-risk cases.
"""
 
with open("model_card.md", "w") as file:
    file.write(model_card)
 
print("Model Card created: model_card.md")
# Out:
# Model Card created: model_card.md

# %%
# Step 5: Create Dataset Datasheet
datasheet = f"""
# Datasheet for Dataset
 
## Dataset Overview
Dataset Name: {dataset_info["Dataset Name"]}
 
Data Source: {dataset_info["Data Source"]}
 
Data Owner: {dataset_info["Data Owner"]}
 
Dataset Version: {dataset_info["Dataset Version"]}
 
## Purpose
The dataset is used to train and evaluate a loan approval prediction model.
 
## Data Classification
The dataset is classified as {dataset_info["Data Classification"]}.
 
## Sensitive Attributes
Sensitive attributes include: {dataset_info["Sensitive Attributes"]}.
 
## Target Variable
The target variable is: {dataset_info["Target Variable"]}.
 
## Privacy Considerations
The dataset may contain personally identifiable information and should be protected using access controls, encryption, and data minimization practices.
 
## Data Quality Considerations
The dataset should be checked for missing values, duplicate records, inaccurate labels, underrepresented groups, and historical bias.
 
## Retention
The dataset retention period is {dataset_info["Data Retention Period"]}.
 
## Governance Notes
The dataset should be reviewed before model training and monitored for changes over time.
"""
 
with open("dataset_datasheet.md", "w") as file:
    file.write(datasheet)
 
print("Dataset Datasheet created: dataset_datasheet.md")

# %%
# Step 6: Create AI Risk Register
risk_register = pd.DataFrame({
    "Risk ID": ["R1", "R2", "R3", "R4", "R5"],
    "Risk": [
        "Model produces biased loan approval outcomes",
        "Sensitive applicant data is exposed",
        "Model decision is difficult to explain",
        "Model performance degrades after deployment",
        "Unauthorized users access model or data"
    ],
    "Category": [
        "Fairness",
        "Privacy",
        "Explainability",
        "Reliability",
        "Security"
    ],
    "Likelihood": ["Medium", "Medium", "High", "Medium", "Low"],
    "Impact": ["High", "High", "Medium", "Medium", "High"],
    "Mitigation": [
        "Conduct fairness testing and bias mitigation",
        "Apply encryption, access controls, and data minimization",
        "Use SHAP or feature importance explanations",
        "Monitor performance and model drift",
        "Implement RBAC, MFA, logging, and audit reviews"
    ],
    "Owner": [
        "Responsible AI Team",
        "Privacy Officer",
        "Data Science Team",
        "MLOps Team",
        "Security Team"
    ],
    "Status": [
        "Open",
        "Open",
        "Open",
        "Open",
        "Open"
    ]
})
 
risk_register
# Out:
#   Risk ID                                          Risk        Category  \
# 0      R1  Model produces biased loan approval outcomes        Fairness
# 1      R2           Sensitive applicant data is exposed         Privacy
# 2      R3        Model decision is difficult to explain  Explainability
# 3      R4   Model performance degrades after deployment     Reliability
# 4      R5       Unauthorized users access model or data        Security
#
#   Likelihood  Impact                                         Mitigation  \
# 0     Medium    High       Conduct fairness testing and bias mitigation
# 1     Medium    High  Apply encryption, access controls, and data mi...
# 2       High  Medium        Use SHAP or feature importance explanations
# 3     Medium  Medium                Monitor performance and model drift
# 4        Low    High    Implement RBAC, MFA, logging, and audit reviews
#
#                  Owner Status
# 0  Responsible AI Team   Open
# 1      Privacy Officer   Open
# ...

# %%
#Save it
 
risk_register.to_csv("ai_risk_register.csv", index=False)
 
print("Risk Register created: ai_risk_register.csv")
# Out:
# Risk Register created: ai_risk_register.csv

# %%
# Step 7: Create Governance Checklist
governance_checklist = pd.DataFrame({
    "Control Area": [
        "Business Approval",
        "Data Review",
        "Privacy Review",
        "Security Review",
        "Fairness Testing",
        "Explainability Review",
        "Human Oversight",
        "Monitoring Plan",
        "Incident Response",
        "Final Governance Approval"
    ],
    "Required Evidence": [
        "Business owner approval",
        "Dataset datasheet",
        "Privacy impact review",
        "Security assessment",
        "Fairness evaluation report",
        "Explainability report",
        "Human review workflow",
        "Monitoring dashboard or plan",
        "AI incident response plan",
        "Signed approval record"
    ],
    "Status": [
        "Pending",
        "Completed",
        "Pending",
        "Pending",
        "Pending",
        "Pending",
        "Pending",
        "Pending",
        "Pending",
        "Pending"
    ]
})
 
governance_checklist
# Out:
#                 Control Area             Required Evidence     Status
# 0          Business Approval       Business owner approval    Pending
# 1                Data Review             Dataset datasheet  Completed
# 2             Privacy Review         Privacy impact review    Pending
# 3            Security Review           Security assessment    Pending
# 4           Fairness Testing    Fairness evaluation report    Pending
# 5      Explainability Review         Explainability report    Pending
# 6            Human Oversight         Human review workflow    Pending
# 7            Monitoring Plan  Monitoring dashboard or plan    Pending
# 8          Incident Response     AI incident response plan    Pending
# 9  Final Governance Approval        Signed approval record    Pending

# %%
#Save it
 
governance_checklist.to_csv("governance_checklist.csv", index=False)
 
print("Governance Checklist created: governance_checklist.csv")
# Out:
# Governance Checklist created: governance_checklist.csv

# %%
# Step 8: Create Approval Record
approval_record = pd.DataFrame({
    "Approver Role": [
        "Business Owner",
        "Model Owner",
        "Compliance Officer",
        "Privacy Officer",
        "Security Reviewer",
        "AI Governance Board"
    ],
    "Approver Name": [
        "Pending",
        "Pending",
        "Pending",
        "Pending",
        "Pending",
        "Pending"
    ],
    "Approval Status": [
        "Pending",
        "Pending",
        "Pending",
        "Pending",
        "Pending",
        "Pending"
    ],
    "Approval Date": [
        "",
        "",
        "",
        "",
        "",
        ""
    ]
})
 
approval_record
# Out:
#          Approver Role Approver Name Approval Status Approval Date
# 0       Business Owner       Pending         Pending
# 1          Model Owner       Pending         Pending
# 2   Compliance Officer       Pending         Pending
# 3      Privacy Officer       Pending         Pending
# 4    Security Reviewer       Pending         Pending
# 5  AI Governance Board       Pending         Pending

# %%
#Save it
approval_record.to_csv("approval_record.csv", index=False)
print("Approval Record created: approval_record.csv")
# Out:
# Approval Record created: approval_record.csv

# %%
# Step 9: Create Compliance Evidence Index
evidence_index = pd.DataFrame({
    "Evidence Item": [
        "Model Card",
        "Dataset Datasheet",
        "AI Risk Register",
        "Governance Checklist",
        "Approval Record",
        "Fairness Report",
        "Explainability Report",
        "Security Assessment Report"
    ],
    "File Name": [
        "model_card.md",
        "dataset_datasheet.md",
        "ai_risk_register.csv",
        "governance_checklist.csv",
        "approval_record.csv",
        "fairness_report.md",
        "explainable_ai_report.md",
        "ai_security_assessment_report.md"
    ],
    "Purpose": [
        "Documents model purpose, use, limitations, and oversight",
        "Documents dataset origin, quality, privacy, and governance details",
        "Tracks AI risks, owners, mitigations, and status",
        "Tracks governance controls and required evidence",
        "Documents deployment approvals",
        "Provides fairness testing evidence",
        "Provides explainability evidence",
        "Provides security testing evidence"
    ]
})
 
evidence_index
# Out:
#                 Evidence Item                         File Name  \
# 0                  Model Card                     model_card.md
# 1           Dataset Datasheet              dataset_datasheet.md
# 2            AI Risk Register              ai_risk_register.csv
# 3        Governance Checklist          governance_checklist.csv
# 4             Approval Record               approval_record.csv
# 5             Fairness Report                fairness_report.md
# 6       Explainability Report          explainable_ai_report.md
# 7  Security Assessment Report  ai_security_assessment_report.md
#
#                                              Purpose
# 0  Documents model purpose, use, limitations, and...
# 1  Documents dataset origin, quality, privacy, an...
# 2   Tracks AI risks, owners, mitigations, and status
# 3   Tracks governance controls and required evidence
# 4                     Documents deployment approvals
# 5                 Provides fairness testing evidence
# ...

# %%
#Save it
 
evidence_index.to_csv("compliance_evidence_index.csv", index=False)
 
print("Compliance Evidence Index created: compliance_evidence_index.csv")
# Out:
# Compliance Evidence Index created: compliance_evidence_index.csv

# %%
# Step 10: Generate Final Governance Summary
summary = f"""
# Governance Documentation Summary
 
## AI System
{model_metadata["Model Name"]}
 
## Purpose
This documentation package supports Responsible AI governance review before deployment.
 
## Documents Created
- Model Card
- Dataset Datasheet
- AI Risk Register
- Governance Checklist
- Approval Record
- Compliance Evidence Index
 
## Key Governance Concerns
The main governance concerns include fairness, privacy, explainability, security, reliability, and human oversight.
 
## Deployment Recommendation
The model should not be deployed until all required governance checklist items are completed and approved by the appropriate stakeholders.
 
## Next Steps
1. Complete fairness testing.
2. Complete explainability analysis.
3. Complete privacy and security reviews.
4. Obtain required approvals.
5. Establish monitoring and incident response procedures.
"""
 
with open("governance_summary.md", "w") as file:
    file.write(summary)
 
print("Governance Summary created: governance_summary.md")
# Out:
# Governance Summary created: governance_summary.md
